# %% [markdown]
# ## OVERFITTING

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df=pd.read_csv(r"C:\Users\Admin\Downloads\overfitting_dataset.csv")

# %%
df
# Out:
#     Study_Hours  Marks
# 0             1      5
# 1             2      1
# 2             3      8
# 3             4      2
# 4             5      9
# 5             6      3
# 6             7     10
# 7             8      4
# 8             9     11
# 9            10      5
# 10            1      6
# 11            2      2
# 12            3      9
# 13            4      3
# 14            5     10
# 15            6      4
# 16            7     11
# 17            8      5
# 18            9     12
# 19           10      6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Study_Hours  20 non-null     int64
#  1   Marks        20 non-null     int64
# dtypes: int64(2)
# memory usage: 452.0 bytes

# %%
df.describe()
# Out:
#        Study_Hours      Marks
# count    20.000000  20.000000
# mean      5.500000   6.300000
# std       2.946898   3.435113
# min       1.000000   1.000000
# 25%       3.000000   3.750000
# 50%       5.500000   5.500000
# 75%       8.000000   9.250000
# max      10.000000  12.000000

# %%
x = df[["Study_Hours"]]
y = df["Marks"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
y_train_pred
# Out:
# array([8.08538423, 7.0050226 , 5.56454043, 6.28478152, 8.08538423,
#        7.36514314, 6.28478152, 5.92466097, 8.44550477, 8.44550477,
#        6.64490206, 5.92466097, 7.72526369, 5.20441989, 6.64490206,
#        7.36514314])

# %%
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)

# %%
print("Training MSE:", train_mse)
print("Testing MSE:", test_mse)
# Out:
# Training MSE: 10.299974886991464
# Testing MSE: 9.333509961072945

# %%
residuals = y_test-y_test_pred
residuals
# Out:
# 0    -0.204420
# 17   -2.725264
# 15   -3.005023
# 1    -4.564540
# Name: Marks, dtype: float64

# %%
plt.figure()
plt.scatter(x_test, residuals)
plt.axhline(0)
plt.xlabel("Study Hours (Test)")
plt.ylabel("Residuals")
plt.title("Residual plot (Test Data)")
plt.show()
